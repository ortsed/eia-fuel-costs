# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import sqlite3
import pandas as pd
pd.set_option("display.max_columns", 500)
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
from sklearn.metrics import f1_score, recall_score, precision_score
from sklearn.metrics import confusion_matrix

# %%
from statsmodels.tsa.stattools import adfuller, acf, pacf

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas.plotting import autocorrelation_plot

# %%
conn = sqlite3.connect("eia")
cursor = conn.cursor()
df = pd.DataFrame(cursor.execute("""select * from combined5""").fetchall())
df.columns = [description[0] for description in cursor.description]
df = df.drop(columns=["index", "level_0"])
df.head()
# Out:
#    average_ash_content  average_heat_content  average_mercury_content  \
# 0                  5.4                23.100                      0.0
# 1                  5.7                22.800                      0.0
# 2                  0.0                 1.039                      0.0
# 3                  0.0                 1.039                      0.0
# 4                  0.0                 1.039                      0.0
#
#    average_sulfur_content  chlorine_content coalmine_county coalmine_msha_id  \
# 0                    0.49               0.0             IMP              N/A
# 1                    0.48               0.0             IMP              N/A
# 2                    0.00               0.0             N/A              N/A
# 3                    0.00               0.0             N/A              N/A
# 4                    0.00               0.0             N/A              N/A
#
#     coalmine_name coalmine_state coalmine_type contract_expiration_date  \
# ...

# %%
lag_acf = acf(df.fuel_cost, nlags=50)
lag_pacf = pacf(df.fuel_cost, nlags=50, method='ols')

# %%
plt.plot(lag_acf, label='acf')
plt.legend()
plt.show()
plt.plot(lag_pacf, label='pacf')
plt.legend();

# %%
options = []
for i,x in enumerate(lag_pacf):
    if len(options) < 10 and x >.25:
        options.append(i)
        print(i, x)
# Out:
# 0 1.0
# 1 0.649762838818847

# %%
not_encode = []
to_encode = []
for fld, fld_type in df.dtypes.items():
    if "object" == fld_type:
        to_encode.append(fld)
    else:
        not_encode.append(fld)
df2 = df[not_encode]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-77e86f4bd205> in <module>
#      10
#      11 plt.figure(figsize=(16,10))
# ---> 12 autocorrelation_plot(df2);
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_misc.py in autocorrelation_plot(series, ax, **kwds)
#     624                 (data[h:] - mean)).sum() / float(n) / c0
#     625     x = np.arange(n) + 1
# --> 626     y = lmap(r, x)
#     627     z95 = 1.959963984540054
#     628     z99 = 2.5758293035489004
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/compat/__init__.py in lmap(*args, **kwargs)
#     130
#     131     def lmap(*args, **kwargs):
# --> 132         return list(map(*args, **kwargs))
#     133
#     134     def lfilter(*args, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_misc.py in r(h)
#     622     def r(h):
# ...

# %%
plt.figure(figsize=(16,10))
autocorrelation_plot(df2)
